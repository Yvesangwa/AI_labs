# %% [markdown]
# # **BUILDING A PYTHON LIBRARY MANAGEMENT SYSTEM**

# %% [markdown]
# ## **1. Project description**
#
# Build a simple Python application to manage a small library. The system will store information about books and members, allow users to add, search, borrow, and return books, save and retrieve data from files or a database, and use an API to obtain additional book information.

# %%
# Import libraries 

import pickle
import sqlite3
import requests

# %% [markdown]
# ## **2. Create a book list and Add two more books**

# %%
# Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")
# Out:
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True

# %%
# Create a list of books

books = ["Python Basics", "Advanced Python", "Data Science with Python"]

print("List of books:", books)
# Out:
# List of books: ['Python Basics', 'Advanced Python', 'Data Science with Python']

# %%
# Add two more books to the list
# Add one book to the end of the list

books.append("Machine Learning")

print(books)
# Out:
# ['Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning']

# %%
# Add the second book at the second position

books.insert(1, "Introduction to AI")

print("Updated book list:", books)
# Out:
# Updated book list: ['Python Basics', 'Introduction to AI', 'Advanced Python', 'Data Science with Python', 'Machine Learning']

# %% [markdown]
# ## **3. Implement a loop to print books with their indices**

# %%
# Loops and range()
print("\nAvailable books:")

# Use a for loop and range() to print books with their indices
for i in range(len(books)):
    print(i+1, books[i])
# Out:
# Available books:
# 1 Python Basics
# 2 Introduction to AI
# 3 Advanced Python
# 4 Data Science with Python
# 5 Machine Learning

# %% [markdown]
# ## **4. Create and implement a user input**

# %%
# User Input to add a new book

new_book = input("Enter a new book title: ")
books.append(new_book)
print("Updated book list:", books)
# Out:
# Updated book list: ['Python Basics', 'Introduction to AI', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Unsupervised ML']

# %% [markdown]
# ## **5. Implement a function to check the book availability**

# %%
# Functions and Conditional Statements
def check_availability(book_name):
# Check if the book is in the list and return True if available, False otherwise
    if book_name in books:
      return True
    else:
      return False
    pass

# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? True

# %% [markdown]
# ## **6. Implement a function to read books from a file**

# %%
# File I/O
def save_books_to_file(filename):
    with open(filename, 'w') as f:
        for book in books:
            f.write(f"{book}\n")

# Implement a function to read books from a file
def read_books_from_file(filename):
    books_from_file = []
    with open(filename, 'r') as f:
        for book in f:
            books_from_file.append(book.strip())
    return books_from_file

# Test file I/O
save_books_to_file("books.txt")

# Save the book
saved_books = read_books_from_file("books.txt")

print(saved_books)
# Out:
# ['Python Basics', 'Introduction to AI', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Unsupervised ML']

# %% [markdown]
# ## **7. Implement a function to load books using pickle**

# %%
# Pickle for serialization
def save_books_pickle(filename):
    with open(filename, 'wb') as f:
        pickle.dump(books, f)

# Implement a function to load books using pickle
def load_books_pickle(filename):
    with open(filename, 'rb') as f:
        books_loaded = pickle.load(f)
    return books_loaded


# Test pickle functions
save_books_pickle("books.pkl")

print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Python Basics', 'Introduction to AI', 'Advanced Python', 'Data Science with Python', 'Machine Learning', 'Unsupervised ML']

# %% [markdown]
# ## **8. Create a function to add books to an SQLite database**

# %%
# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

# Implement a function to add a book to the SQLite database
def add_book_to_db(title, quantity):
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()

    cursor.execute(
        "INSERT INTO books (title, quantity) VALUES (?, ?)",
        (title, quantity)
    )

    conn.commit()
    conn.close()

# Test database functions
create_books_table()

add_book_to_db("Python for Beginners", 10)

# %%
# 9. Web API Interaction (GitHub API)
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}
    response = requests.get(url, params=params)
    data = response.json()
    return [repo['name'] for repo in data['items'][:5]]

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'project-based-learning']
#
# Library Management System operations completed.
